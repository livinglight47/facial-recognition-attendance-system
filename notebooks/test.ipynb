# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import torch

# %%
torch.__version__
# Out:
# '2.9.0+cu130'

# %%
model = YOLO("runs/detect/face_yolo11n/weights/best.pt")

# %%
image_path = "test3.jpg"

# %%
results = model.predict(
    source=image_path,
    save=False,
    conf=0.8,
    imgsz=1280,
    device=0  # or "cpu" if no GPU
)
# Out:
# image 1/1 e:\facial-recognition-attendance-system\notebooks\test3.jpg: 992x1280 4 faces, 32.6ms
# Speed: 28.2ms preprocess, 32.6ms inference, 10.9ms postprocess per image at shape (1, 3, 992, 1280)

# %%
annotated_frame = results[0].plot()

# %%
annotated_frame = cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(8, 8))
plt.imshow(annotated_frame)
plt.axis("off")
plt.show()
